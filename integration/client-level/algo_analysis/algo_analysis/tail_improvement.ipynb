# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import math

# %%
algos = ['baseline', 'hedging', 'random', 'linnos', 'flashnet']
percentiles_characteristics = ['avg', 'p50.0', 'p80.0', 'p90.0', 'p95.0', 'p96.0', 'p97.0', 'p98.0', 'p99.0', 'p99.9', 'p99.99']

# %%
grouping_dirs = {}
grouping_dirs['data'] = "/mnt/heimdall-exp/Heimdall/integration/client-level/data"

# %% [markdown]
# ## Examine the Stats

# %%
col_names = ['algo', 'grouping_dir', 'trace_dir'] + percentiles_characteristics
df = pd.DataFrame(columns = col_names)

for key, grouping_dir in grouping_dirs.items():
    trace_dirs_1 = [os.path.join(grouping_dir, dir) for dir in os.listdir(grouping_dir) if os.path.isdir(os.path.join(grouping_dir, dir))]
    trace_dirs_2 = []
    for trace_dir in trace_dirs_1:
        trace_dirs_2.extend([os.path.join(trace_dir, dir) for dir in os.listdir(trace_dir) if os.path.isdir(os.path.join(trace_dir, dir))])
    trace_dirs_3 = []
    for trace_dir in trace_dirs_2:
        trace_dirs_3.extend([os.path.join(trace_dir, dir) for dir in os.listdir(trace_dir) if os.path.isdir(os.path.join(trace_dir, dir))])
    trace_dirs_4 = []
    for trace_dir in trace_dirs_3:
        trace_dirs_4.extend([os.path.join(trace_dir, dir) for dir in os.listdir(trace_dir) if os.path.isdir(os.path.join(trace_dir, dir))])
    trace_dirs = trace_dirs_4

    for trace_dir in trace_dirs:
        for algo in algos:
            this_data = [algo, key, trace_dir]
            try:
                f = open(os.path.join(trace_dir, algo, "latency_characteristic.stats"), "r")
                latency_characteristic = f.readlines()
                for p in percentiles_characteristics:
                    for line in latency_characteristic:
                        if line.split(' = ')[0] == p:
                            this_data.append(float(line.split(' = ')[1].split(' us')[0]))
                df.loc[len(df)] = this_data
            except:
                print("CHAR", algo, trace_dir)

df
# Out:
#         algo grouping_dir                                          trace_dir  \
# 0   baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 1    hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 2     random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 3     linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 4   flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 5   baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 6    hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 7     random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 8     linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 9   flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 10  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 11   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 12    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 13    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 14  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 15  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 16   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 17    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 18    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 19  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 20  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 21   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 22    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 23    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 24  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 25  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 26   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 27    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 28    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 29  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 30  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 31   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 32    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 33    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 34  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 35  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 36   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 37    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 38    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 39  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 40  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 41   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 42    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 43    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 44  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 45  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 46   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 47    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 48    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 49  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 50  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 51   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 52    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 53    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 54  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 55  baseline         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 56   hedging         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 57    random         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 58    linnos         data  /mnt/heimdall-exp/Heimdall/integration/client-...
# 59  flashnet         data  /mnt/heimdall-exp/Heimdall/integration/client-...
#
#            avg  p50.0   p80.0   p90.0   p95.0   p96.0   p97.0    p98.0  \
# 0   269.034722  124.0   432.0   626.0   785.0   833.0   896.0   997.00
# 1   258.005206  132.0   447.0   648.0   808.0   857.0   920.0  1025.00
# 2   207.805341   91.0   257.0   503.0   691.0   745.0   816.0   922.00
# 3   369.385808  218.0   554.0   748.0   909.0   962.0  1036.0  1178.00
# 4   151.206212  100.0   151.0   248.0   441.0   498.0   568.0   673.00
# 5   128.402077   93.0   202.0   307.0   387.0   412.0   444.0   487.00
# hedging   0.269428  0.183667  0.441917  0.625583  0.786417  0.838417
# random    0.210470  0.110667  0.309583  0.524500  0.711917  0.770500
# linnos    0.214380  0.144917  0.296083  0.428667  0.594250  0.658750
# flashnet  0.162207  0.099000  0.209083  0.328417  0.512333  0.577167
#
#              p97.0     p98.0     p99.0     p99.9    p99.99
# algo
# baseline  0.908917  1.016333  1.263333  3.157142  4.839740
# hedging   0.907667  1.010583  1.173688  1.492681  1.927944
# random    0.848000  0.965377  1.216333  3.101232  5.017769
# linnos    0.739167  0.855583  1.150083  2.534582  4.886273
# flashnet  0.659083  0.775500  1.012167  2.488838  4.714522

# %%
plt.rcParams.update({'font.size': 16})

algos = ['baseline', 'hedging', 'random', 'linnos', 'flashnet']
label = ['Baseline', 'Hedging', 'Random', 'LinnOS', 'FlashNet']
font_colors = ['black', 'black', 'black', 'black', 'white']
colors = ['red', 'magenta', 'orange', 'lime', 'blue']

metric = "avg"

fig, ax = plt.subplots(figsize=(2.4, 3.4))
ax.bar(algos, collection_ms[metric], label=label, color=colors)
# ax.set_title('Latency at '+ metric +' (Light-Light)')
ax.set_ylabel('Average Latency (ms)')
# ax.set_ylim(0, 0.5)
# ax.set_yticklabels(["0", ".1", ".2", ".3", ".4", ".5"])
ax.set_xticklabels(label, rotation=90)
ax.set_xlabel('Algorithms')
ax.tick_params(axis='x', which='major', pad=-10)
for ticklabel, tickcolor in zip(fig.gca().get_xticklabels(), font_colors):
    ticklabel.set_color(tickcolor)
    ticklabel.set_horizontalalignment("center")
    ticklabel.set_verticalalignment("bottom")
# plt.text(-0.75, 0.5125, "(d) Light-Heavy", fontweight='bold')
# plt.text(4.72, 0.165, "et", rotation=90)
plt.savefig(os.path.join("eval-client-avg.eps"), dpi=200, bbox_inches='tight', format='eps')
plt.show()
# Out:
# /tmp/ipykernel_287435/1460062262.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(label, rotation=90)

# %%
# Draw baseline vs flashnet line chart

algos = ['baseline', 'hedging', 'random', 'linnos', 'flashnet']
line_legend = ['Baseline', 'Hedging', 'Random', 'LinnOS', 'FlashNet']
colors = ['red', 'magenta', 'orange', 'lime', 'blue']
styles = ['s-', '|-', 'x-.', 'd-', '*-.']

x_labels = ["avg", "p80.0", "p90.0", "p95.0", "p99.0", "p99.9", "p99.99"]
x_ticks = ["50", "80", "90", "95", "99", "99.9", "99.99"]

fig, ax = plt.subplots(figsize=(4.1, 2.9))
for idx, algo in enumerate(algos):
    ax.plot(np.arange(len(x_labels)), collection_ms.loc[algo][x_labels].values, styles[idx], label=line_legend[idx], color=colors[idx], linewidth=1.5)

handles, labels = ax.get_legend_handles_labels()
print(labels)

ax.legend([handles[0], handles[2], handles[3], handles[4], handles[1]], [labels[0], labels[2], labels[3], labels[4], labels[1]], loc='upper left', frameon=False, labelspacing=0.25, columnspacing=0.5, borderpad=-0.2, handletextpad=0.2, handlelength=2)
ax.set_xticks(np.arange(len(x_ticks)), x_ticks)
ax.set_xticklabels(x_ticks, rotation=35, ha='center')
# add y label
# ax.set_ylim(0, 8)
ax.set_ylabel("Read Lat. (ms)")
ax.set_xlabel("Percentile")
ax.xaxis.set_label_coords(0.5, -0.2)
ax.yaxis.set_label_coords(-0.085, 0.5)
plt.savefig(os.path.join("eval-client-line.eps"), dpi=200, bbox_inches='tight', format='eps')
plt.show()
# Out:
# ['Baseline', 'Hedging', 'Random', 'LinnOS', 'FlashNet']
